# %% [markdown]
# ### Business understanding

# %% [markdown]
# ### Data understanding

# %% [markdown]
# ### Data preparation

# %%
import pandas as pd

df = pd.read_csv('data/car data.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df = df.drop_duplicates(keep='first')

# %%
df2 = pd.get_dummies(df[['Fuel_Type', 'Seller_Type','Transmission']],drop_first=True)
df2
# Out:
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                   0                 1                       0
# 1                   1                 0                       0
# 2                   0                 1                       0
# 3                   0                 1                       0
# 4                   1                 0                       0
# ..                ...               ...                     ...
# 296                 1                 0                       0
# 297                 0                 1                       0
# 298                 0                 1                       0
# 299                 1                 0                       0
# 300                 0                 1                       0
#
#      Transmission_Manual
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 296                    1
# 297                    1
# 298                    1
# 299                    1
# 300                    1
#
# [299 rows x 4 columns]

# %%
df = pd.concat([df, df2], axis=1)
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0        Dealer       Manual      0                 0                 1
# 1        Dealer       Manual      0                 1                 0
# 2        Dealer       Manual      0                 0                 1
# 3        Dealer       Manual      0                 0                 1
# 4        Dealer       Manual      0                 1                 0
# ..          ...          ...    ...               ...               ...
# 296      Dealer       Manual      0                 1                 0
# 297      Dealer       Manual      0                 0                 1
# 298      Dealer       Manual      0                 0                 1
# 299      Dealer       Manual      0                 1                 0
# 300      Dealer       Manual      0                 0                 1
#
#      Seller_Type_Individual  Transmission_Manual
# 0                         0                    1
# 1                         0                    1
# 2                         0                    1
# 3                         0                    1
# 4                         0                    1
# ..                      ...                  ...
# 296                       0                    1
# 297                       0                    1
# 298                       0                    1
# 299                       0                    1
# 300                       0                    1
#
# [299 rows x 13 columns]

# %%
#independent variables.
X = df.drop(columns=['Selling_Price','Car_Name','Present_Price'])
#target
y = df['Selling_Price']

# %% [markdown]
# ### Modeling

# %% [markdown]
# ### Evaluation
